# %%
#| hide
from zenpy_garden.core import *

# %% [markdown]
# # zenpy-garden
#
# > A FastHTML wrapper for Zendesk Garden CSS

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install zenpy_garden in Development mode

# %% [markdown]
# ```sh
# # make sure zenpy_garden package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to zenpy_garden
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/shawnemhe/zenpy-garden.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c shawnemhe zenpy_garden
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install zenpy_garden
# ```
#
#
# [repo]: https://github.com/shawnemhe/zenpy-garden
# [docs]: https://shawnemhe.github.io/zenpy-garden/
# [pypi]: https://pypi.org/project/zenpy-garden/
# [conda]: https://anaconda.org/shawnemhe/zenpy-garden

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/shawnemhe/zenpy-garden
# [docs]: https://shawnemhe.github.io/zenpy-garden/
# [pypi]: https://pypi.org/project/zenpy-garden/
# [conda]: https://anaconda.org/shawnemhe/zenpy-garden

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
